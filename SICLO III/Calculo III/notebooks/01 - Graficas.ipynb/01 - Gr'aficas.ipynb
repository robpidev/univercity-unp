# %%
using Plots

# %% [markdown]
# $$y^2 = x -1$$

# %%
t = -1:0.01:1
x = t.^2 .+ 1

wireframe(x, t, t)
# Out:
# Arrays have incorrect length or dimension.
# Arrays have incorrect length or dimension.
# Arrays have incorrect length or dimension.
